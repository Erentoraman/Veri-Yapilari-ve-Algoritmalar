# %% [markdown]
# Veri yapıları ve Algoritmalar dersi kodlama çıktısıdır. İGÜ İSTKA Siber Akademi Merkezi 21.08.2024

# %%
print("Merhaba, Ders 3") # print ekrana çıktı veren bir koddur.
# Out:
# Merhaba, Ders 3

# %%
import sys # import python programlama dilinde yazılıma kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive  # google colab - drive bağlantısını sağlar.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/Veriyapilari-istka")
# !pwd # bize kodun çıktısını dosya yolu olarak veren kod bloğudur.
# Out:
# /content/drive/My Drive/Veriyapilari-istka

# %% [markdown]
# PYTHON Koşul Yapıları
#
# if Koşul yapısı -> belirtilen şart doğruysa (True) bir bloğun çalıştırılmasını sağlamaktadır.
#
# if-else Koşul yapısı -> if bloğu sağlanmazsa, else bloğu çalıştırılır.
#
# if-elif-else Koşul yapısı -> Birden fazla koşul kontrol etmek için elif (else if) kullanılır. İlk doğru koşul bulunana kadar kontrol devam eder. Hiçbiri doğru değilse, else bloğu çalıştırılır.
#
# İç İçe Koşullar
#
# Mantıksal Operatörler ile Koşul Yapıları

# %%
# if Koşul yapısı

x = 8

if x > 4:
    print("x, 4'ten büyüktür.")
# Out:
# x, 4'ten büyüktür.

# %%
# if-else Koşulu yapısı

x = 4

if x > 8:
    print("x, 8'den büyüktür.")
else:
    print("x, 8'den küçük veya eşittir.")
# Out:
# x, 8'den küçük veya eşittir.

# %%
# if-elif-else Koşul Yapısı

x = 8

if x > 10:
    print("x, 10'dan büyüktür.")
elif x > 5:
    print("x, 5'ten büyüktür ama 10'dan küçük veya eşittir.")
else:
    print("x, 5'ten küçük veya eşittir.")
# Out:
# x, 5'ten büyüktür ama 10'dan küçük veya eşittir.

# %%
# İç İçe Koşul Yapısı

x = 12
y = 8

if x > 10:
    if y > 5:
        print("x, 10'dan büyük ve y, 5'ten büyüktür.")  # Bu satır çalışır
    else:
        print("x, 10'dan büyük ama y, 5'ten küçük veya eşittir.")
else:
    print("x, 10'dan küçük veya eşittir.")
# Out:
# x, 10'dan büyük ve y, 5'ten büyüktür.

# %%
# Mantıksal Operatörler ile Koşullar

x = 7
y = 3

# 'and' operatörü ile
if x > 5 and y > 2:
    print("x, 5'ten büyük ve y, 2'den büyüktür.")  # Bu satır çalışır

# 'or' operatörü ile
if x > 5 or y > 5:
    print("x veya y, 5'ten büyüktür.")  # Bu satır çalışır

# 'not' operatörü ile
if not (x > 10):
    print("x, 10'dan büyük değildir.")  # Bu satır çalışır
# Out:
# x, 5'ten büyük ve y, 2'den büyüktür.
# x veya y, 5'ten büyüktür.
# x, 10'dan büyük değildir.

# %%
# Örnek 1: Not Sistemi

notu = 44 #Not farkını gösterilecek...

if notu >= 90:
    print("Harf notu: A")
elif notu >= 80:
    print("Harf notu: B")
elif notu >= 70:
    print("Harf notu: C")
elif notu >= 60:
    print("Harf notu: D")
else:
    print("Harf notu: F") # Bu satır çalışır
# Out:
# Harf notu: F

# %%
# Örnek 2: Yaş Kontrolü

yas = 20

if yas < 18:
    print("Reşit değilsiniz.")
elif yas < 21:
    print("Reşitsiniz ama içecek satın alamazsınız.") #Bu satır çalışacak
else:
    print("İçecek satın alabilirsiniz.")
# Out:
# Reşitsiniz ama içecek satın alamazsınız.

# %%
# Örnek 3: Sayı Pozitif, Negatif veya Sıfır mı?

sayi = int(input("Bir sayı girin:"))

if sayi > 0:
    print("Sayı pozitiftir.")
elif sayi < 0:
    print("Sayı negatiftir.")
else:
    print("Sayı sıfırdır.")
# Out:
# Bir sayı girin:-44
# Sayı negatiftir.
